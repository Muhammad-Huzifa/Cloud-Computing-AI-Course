# %% [markdown]
# # Pandas Titanic Classroom Practice Notebook
#
# ## Empty Code Cells with Simple Teaching Notes
#
# The Titanic dataset contains information about passengers, including age, sex, passenger class, fare and survival status.
#
# - **Survived = 0:** The passenger did not survive
# - **Survived = 1:** The passenger survived
# - **Pclass:** Passenger class: 1st, 2nd or 3rd
# - **SibSp:** Number of siblings or spouses aboard
# - **Parch:** Number of parents or children aboard
#
# Use this notebook to show how a real dataset is loaded, explored, cleaned, filtered, grouped, visualized and saved. Read the short note in each section, discuss why the operation is needed, and then type the code in the empty cell.

# %% [markdown]
# ## 1. Import the Libraries
#
# Pandas works with tables, NumPy performs numerical calculations and Matplotlib creates charts.
#
# Pandas will manage the passenger table, NumPy will calculate numerical values, and Matplotlib will draw the charts. Import these three libraries first so their tools are available throughout the notebook. Use the common short names `pd`, `np` and `plt`.

# %%
import pandas
import numpy

# %%
import pandas as pd

# Pehle din direct Python dictionary se table banayein
data = {
    "Name": ["Ali", "Sara", "Zaid", "Hira", "Usman"],
    "Department": ["CS", "BBA", "Medical", "CS", "BBA"],
    "Study_Hours": [12, 18, 25, 8, 15],
    "Exam_Score": [78, 88, 95, 45, 82],
    "Passed": [True, True, True, False, True],
}
data
arrange = pd.DataFrame(data)
arrange
# Out:
#     Name Department  Study_Hours  Exam_Score  Passed
# 0    Ali         CS           12          78    True
# 1   Sara        BBA           18          88    True
# 2   Zaid    Medical           25          95    True
# 3   Hira         CS            8          45   False
# 4  Usman        BBA           15          82    True

# %%
dataset = pd.read_csv(r"C:\Users\Muhammad Huzifa\Desktop\Huawei_HCCDA_AI\Cloud-Computing-AI-Course\Cloud-Computing-AI-Course\Week-3\dataset\titanic_dataset\Titanic_test.csv")
dataset
print(dataset["Name"])
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: str

# %% [markdown]
# ## 3. View the First Rows
#
# The head function displays the first five passenger records.
#
# Before changing the data, look at a small sample. Display the first five passengers and point out that each row represents one passenger while each column represents one type of information.

# %%
dataset.head() 
dataset.describe() 
dataset.isna()

dataset.dropna()
dataset.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# ## 4. View the Last Rows
#
# The tail function displays the last five passenger records.
#
# Now look at the final five passengers. This is a quick way to confirm that the dataset loaded to the end and to inspect records from another part of the table.

# %% [markdown]
# ## 5. Check the Dataset Size
#
# Shape tells us the number of rows and columns.
#
# Suppose someone asks how large the dataset is. The first shape value gives the number of passenger records and the second gives the number of columns. Display both values separately so students can identify rows and columns.

# %% [markdown]
# ## 6. View the Column Names
#
# Columns shows the names of all variables in the dataset.
#
# When a new dataset arrives, we may not know what information it contains. Display all column names and briefly connect familiar names such as Age, Sex, Fare, Pclass and Survived with their meanings.

# %% [markdown]
# ## 7. Check Data Types and Missing Values
#
# Info shows column names, data types and the number of available values.
#
# Use `info()` as a quick health check for the table. Ask students to notice the column names, data types and non-null counts. A smaller non-null count shows that some values are missing.

# %% [markdown]
# ## 8. View the Statistical Summary
#
# Describe calculates count, mean, minimum, maximum and other statistics for numerical columns.
#
# A dataset may contain hundreds of passengers, so reading every row is not useful. Use `describe()` to summarize the numerical columns. Focus on simple values such as count, average, minimum and maximum rather than explaining every statistic.

# %% [markdown]
# ## 9. Find Missing Values
#
# The following code counts empty values in every column.
#
# Empty values can cause problems during calculations and model training. Check every column and count how many values are missing. The columns with larger counts will need attention during cleaning.

# %% [markdown]
# ## 10. Handle Missing Values
#
# - Replace missing Age values with the median age.
# - Replace missing Fare values with the median fare.
# - Replace missing Embarked values with the most common port.
# - Remove Cabin because it contains many missing values.
#
# Clean the important columns without making the example complicated. Fill missing Age and Fare values with their medians, fill Embarked with its most common value, and remove Cabin because too many cabin values are unavailable. Explain that cleaning prepares the table for reliable analysis.

# %% [markdown]
# ## 11. Check Missing Values Again
#
# Run the same check to confirm that the important missing values are removed.
#
# Repeat the missing-value count after cleaning. Compare it with the earlier result so students can see that the operation changed the dataset instead of accepting the success message without checking.

# %% [markdown]
# ## 12. Check and Remove Duplicate Records
#
# PassengerId uniquely identifies each passenger, so repeated IDs can be removed safely.
#
# Duplicate records can count the same passenger more than once and produce incorrect results. Count the duplicates first, then remove repeated PassengerId values because each passenger should have one unique ID.

# %% [markdown]
# ## 13. Select Important Columns
#
# We can select only the columns needed for a task.
#
# Sometimes a task needs only a few columns rather than the complete table. Create a smaller table containing passenger ID, name, sex, age, class and survival status, then display its first rows.

# %% [markdown]
# ## 14. Select Data with loc
#
# Loc selects rows and columns by their labels.
#
# Use `loc` when selecting data by row and column labels. Show rows labelled 0 through 4 and only Name, Sex, Age and Survived. Point out that the ending label 4 is included.

# %% [markdown]
# ## 15. Select Data with iloc
#
# Iloc selects rows and columns by their numerical positions.
#
# Use `iloc` when selecting by numerical positions. Show the first five rows and the first four columns. Point out that the ending position is not included, so position 5 stops before the sixth row.

# %% [markdown]
# ## 16. Filter Surviving Passengers
#
# This condition keeps only passengers whose Survived value is 1.
#
# Suppose we want to study only the passengers who survived. Keep rows where Survived equals 1, store them in a new DataFrame, and display a few useful columns. The original DataFrame still contains every passenger.

# %% [markdown]
# ## 17. Filter Using Two Conditions
#
# This example keeps female passengers who survived.
#
# Now answer a more specific question: which female passengers survived? Combine the Sex and Survived conditions so a row is kept only when both statements are true, then display the first matching passengers.

# %% [markdown]
# ## 18. Sort Passengers by Fare
#
# The highest fares will appear first.
#
# To find passengers who paid the most, sort the Fare column from highest to lowest. Display the first rows after sorting and compare the fare with passenger class.

# %% [markdown]
# ## 19. Create New Columns
#
# FamilySize combines the passenger, siblings, spouse, parents and children. Status changes 0 and 1 into readable labels.
#
# Create information that was not directly provided in the original table. FamilySize combines the passenger with siblings, spouse, parents and children. Status changes the numerical survival values into words that are easier to read.

# %% [markdown]
# ## 20. Calculate Survival Rate by Sex
#
# Groupby places male and female passengers into separate groups. Mean calculates the survival rate.
#
# Separate passengers into male and female groups, then calculate the average of the Survived column. Because Survived contains only 0 and 1, its average represents the survival proportion. Multiply by 100 to express it as a percentage.

# %% [markdown]
# ## 21. Calculate Survival Rate by Passenger Class
#
# This compares the survival percentages of first, second and third class.
#
# Use the same grouping idea for first, second and third class. The result lets students compare whether passenger class was related to survival percentage.

# %% [markdown]
# ## 22. Analyse Age with NumPy
#
# The Age column is converted into a NumPy array before calculating basic statistics.
#
# Convert the cleaned Age column into a NumPy array. Use it to calculate the average age, middle age, youngest passenger and oldest passenger. This connects the earlier NumPy lesson with a real dataset.

# %% [markdown]
# ## 23. Visualize Passenger Outcomes
#
# A bar chart compares passengers who survived with those who did not.
#
# Count the two survival outcomes and draw a bar for each one. Use different colours so the categories are easy to compare, then add a clear title and axis labels. The bar heights show how many passengers belonged to each outcome.

# %% [markdown]
# ## 24. Visualize the Age Distribution
#
# A histogram shows how passenger ages are distributed.
#
# A histogram groups ages into ranges rather than showing every passenger separately. Use 20 groups and explain that taller bars represent age ranges containing more passengers.

# %% [markdown]
# ## 25. Visualize Survival Rate by Sex
#
# This chart compares the survival percentages of male and female passengers.
#
# Use the survival percentages already calculated for male and female passengers. Draw one bar for each group and keep the vertical axis between 0 and 100 because the values are percentages.

# %% [markdown]
# ## 26. Visualize Survival Rate by Passenger Class
#
# This chart compares survival percentages across the three passenger classes.
#
# Use the class survival percentages to draw three bars for first, second and third class. Students should compare the bar heights and describe the pattern they observe before you explain it.

# %% [markdown]
# ## 27. Save the Cleaned Dataset
#
# The final DataFrame is saved as a new CSV file in the Downloads folder.
#
# The cleaned DataFrame currently exists only during the notebook session. Save it as a new CSV file so it can be reused later. Do not save the DataFrame index as an extra column, and keep the original raw file unchanged.

# %% [markdown]
# ## 28. Student Practice
#
# 1. Filter passengers younger than 18.
# 2. Find passengers who paid more than 50.
# 3. Calculate the average fare for each passenger class.
# 4. Count passengers from each embarkation port.
# 5. Create a bar chart showing the number of passengers in each class.
#
# Let students complete one question at a time using the cleaned `df`. Ask them to first say which column and condition they need. For the grouping questions, remind them that the category comes first and the value to calculate comes second. For the chart, they can count the three passenger classes and use those counts as the bar heights.

# %% [markdown]
# ## Ready for Classroom Practice
#
# Every code cell is intentionally empty. Use the short teaching note above each cell to remember the example, explain its purpose, and type the code with the students.

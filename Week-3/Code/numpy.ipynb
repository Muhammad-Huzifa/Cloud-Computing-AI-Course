# %% [markdown]
# # NumPy Live Teaching Notebook
#
# ## Empty Code Cells with Example Hints
#
# NumPy is a Python library used for numerical data, arrays, matrices and fast calculations.
#
# Follow each short task and hint, then type the code live in the empty cell below it. The examples move from basic arrays to indexing, slicing, reshaping, broadcasting, statistics and matrix multiplication.

# %% [markdown]
# ## Import NumPy
#
# The short name **np** is commonly used for NumPy.

# %% [markdown]
# ## 1. Python Lists and NumPy Arrays
#
# A Python list stores values, while a NumPy array performs numerical operations directly.
#
#
#
# - Use the values **1, 2, 3** in both a Python list and a NumPy array.
# - Add each object to itself.
# - **Expected:** The list has six values, while the array becomes **2, 4, 6**.

# %% [markdown]
# ### Example 2: Multiplying values
#
#
# - Multiply the same list and array by **2**.
# - **Expected:** The list repeats, while the array values become **2, 4, 6**.

# %%
# Out:
# array([20, 50])

# %% [markdown]
# ## 2. Create Arrays from Lists
#
# The array function converts a Python list into a NumPy array.
#
#
#
# - Start with the marks **70, 80, 90, 85** in a Python list.
# - Convert the list into a NumPy array.
# - **Expected:** A one-dimensional array containing four marks.

# %% [markdown]
# ### Example 2: Create a two-dimensional array
#
# #### Live example reminder
#
# - Create marks for two students: **70, 80, 90** and **65, 75, 85**.
# - Convert the nested list into a NumPy array.
# - **Expected:** A **2 × 3** array.

# %% [markdown]
# ## 3. Array Dimensions and Properties
#
# - **ndim:** Number of dimensions
# - **shape:** Size of each dimension
# - **size:** Total number of values
# - **dtype:** Type of stored values
#
# ### Example 1: Properties of a one-dimensional array
#
# #### Live example reminder
#
# - Create an array with **10, 20, 30, 40**.
# - Display its dimensions, shape, size and data type.
# - **Expected:** **1** dimension, shape **(4,)** and size **4**.

# %% [markdown]
# ### Example 2: Properties of a two-dimensional array
#
#
# - Create a table with rows **1, 2, 3** and **4, 5, 6**.
# - Display its dimensions, shape, size and data type.
# - **Expected:** **2** dimensions, shape **(2, 3)** and size **6**.

# %% [markdown]
# ## 4. Create Special Arrays
#
# NumPy can create common arrays without entering every value manually.
#
# ### Example 1: Zeros and ones
#
# #### Live example reminder
#
# - Create one **2 × 3** array filled with zeros and another filled with ones.
# - **Hint:** Give the required shape as a tuple to `zeros()` and `ones()`.
# - **Expected:** Two arrays with two rows and three columns.

# %% [markdown]
# ### Example 2: Arange, linspace and random values
#
#
# - Create even values from **0 to 8**, five evenly spaced values from **0 to 1**, and five random integers from **1 to 10**.
# -  Use `arange()` for a step, `linspace()` for a count and `randint()` for integers.
# - Set the random seed to **42** so the classroom result stays the same.
# - **Expected:** The first sequence is **0, 2, 4, 6, 8**.

# %% [markdown]
# ## 5. Array Data Types
#
# The data type tells us whether an array stores integers, decimal numbers or another type.
#
# ### Example 1: Integer and decimal arrays
#
# #### Live example reminder
#
# - Create one array with **1, 2, 3** and another with **1.5, 2.5, 3.5**.
# - Display the data type of each array.
# - **Hint:** Check the `dtype` attribute.
# - **Expected:** The first is an integer type and the second is a floating-point type.

# %% [markdown]
# ### Example 2: Convert integers into decimal numbers
#
#
# - Create an integer array containing **10, 20, 30**.
# - Convert it to decimal values.
# -  Use the `astype()` method with the float type.
# - **Expected:** The values stay the same but display with decimal points.

# %% [markdown]
# ## 6. Array Indexing
#
# Indexing selects one value. Python starts counting positions from zero.
#
# ### Example 1: Index a one-dimensional array
#
#
# - Use the scores **55, 65, 75, 85, 95**.
# - Select the first, third and last values.
#  Use positions **0**, **2** and **-1**.
# - **Expected:** **55, 75, 95**.

# %% [markdown]
# ### Example 2: Index a two-dimensional array
#
# #### Live example reminder
#
# - Create the matrix **[10, 20, 30]** and **[40, 50, 60]**.
# - Select the first row's second value and the second row's third value.
# - **Expected:** **20** and **60**.

# %% [markdown]
# ## 7. Array Slicing
#
# Slicing selects a range of values. The ending position is not included.
#
# ### Example 1: Slice a one-dimensional array
#
# #### Live example reminder
#
# - Use **10, 20, 30, 40, 50, 60**.
# - Select positions 1 to 3, the first three values and everything from position 3 onward.
# - **Expected:** **20–40**, **10–30**, and **40–60**.

# %% [markdown]
# ### Example 2: Slice a two-dimensional array
#
# #### Live example reminder
#
# - Create a **3 × 4** table containing the values **1 to 12**.
# - Select the first two rows, then select the last two columns.
# -  Use a comma to separate row slicing from column slicing.
# - **Expected:** A **2 × 4** result, then a **3 × 2** result.

# %% [markdown]
# ## 8. Change Array Values
#
# An array value can be updated by using its position.
#
# ### Example 1: Change one value
#
# #### Live example reminder
#
# - Create ages **18, 19, 20, 21**.
# - Replace the second age with **25**.
# - **Expected:** **18, 25, 20, 21**.

# %% [markdown]
# ### Example 2: Change a complete row
#
#
# - Create two rows of marks: **60, 70, 80** and **65, 75, 85**.
# - Replace the complete first row with **90, 92, 94**.
# - **Expected:** Only the first row changes.

# %% [markdown]
# ## 9. Reshape Arrays
#
# Reshaping changes the number of rows and columns without changing the values. The total number of values must stay the same.
#
# ### Example 1: Change a row into a 3 × 4 array
#
# #### Live example reminder
#
# - Create the values **1 to 12**.
# - Reshape them into **3 rows and 4 columns**.
# - **Hint:** Generate 12 values first, then use `reshape()`.
# - **Check:** **3 × 4 = 12**, so no value is added or removed.

# %% [markdown]
# ### Example 2: Change the same values into a 2 × 6 array
#
# #### Live example reminder
#
# - Reuse the values **1 to 12** and reshape them into **2 rows and 6 columns**.
# - **Hint:** The same 12 values can use any compatible shape.
# - **Expected:** A **2 × 6** array.

# %% [markdown]
# ## 10. Flatten and Transpose Arrays
#
# Flatten converts a multidimensional array into one line. Transpose changes rows into columns.
#
# ### Example 1: Flatten an array
#
# #### Live example reminder
#
# - Create a **2 × 3** array using the values **1 to 6**.
# - Convert it into one line.
# - **Hint:** Use the `flatten()` method.
# - **Expected:** A one-dimensional array containing six values.

# %% [markdown]
# ### Example 2: Transpose an array
#
# #### Live example reminder
#
# - Create the rows **10, 20, 30** and **40, 50, 60**.
# - Change rows into columns.
# - **Expected:** The shape changes from **2 × 3** to **3 × 2**.

# %% [markdown]
# ## 11. Arithmetic Operations
#
# NumPy applies calculations to every value in an array.
#
# ### Example 1: Calculate with one number
#
# #### Live example reminder
#
# - Use prices **100, 200, 300**.
# - Add **10**, subtract **20**, multiply by **2**, and divide by **10**.
# - **Expected:** Every price is changed independently.

# %% [markdown]
# ### Example 2: Calculate with two arrays
#
# #### Live example reminder
#
# - Use arrays **10, 20, 30** and **1, 2, 3**.
# - Perform addition, subtraction and multiplication.
# - **Hint:** NumPy matches values at the same positions.
# - **Expected:** Addition gives **11, 22, 33**; multiplication gives **10, 40, 90**.

# %% [markdown]
# ## 12. Broadcasting
#
# Broadcasting allows NumPy to apply a smaller value or array across a larger array.
#
# ### Example 1: Add one value to every array element
#
# #### Live example reminder
#
# - Create score rows **60, 70, 80** and **65, 75, 85**.
# - Give every score a bonus of **5**.
# - **Expected:** Every value increases by 5.

# %% [markdown]
# ### Example 2: Add different bonus marks to each subject
#
# #### Live example reminder
#
# - Reuse the score table and create subject bonuses **2, 3, 1**.
# - Add the bonus array to the score table.
# - **Expected:** The first row becomes **62, 73, 81**.

# %% [markdown]
# ## 13. Filter Array Values
#
# A condition creates True and False values. NumPy keeps the values where the condition is True.
#
# ### Example 1: Keep marks greater than or equal to 70
#
# #### Live example reminder
#
# - Use exam marks **55, 68, 72, 84, 91**.
# - Keep only marks greater than or equal to **70**.
# - **Expected:** **72, 84, 91**.

# %%
# Out:
# [72 83 94]

# %% [markdown]
# ### Example 2: Keep only even numbers
#
# #### Live example reminder
#
# - Use the whole numbers **1 to 8**.
# - Keep only the even numbers.
# - **Expected:** **2, 4, 6, 8**.

# %% [markdown]
# ## 14. Numerical and Statistical Operations
#
# NumPy can calculate totals, averages, middle values and the spread of data.
#
# ### Example 1: Statistics for one array
#
# #### Live example reminder
#
# - Use the values **60, 70, 80, 90**.
# - Find the sum, mean, median, minimum, maximum and standard deviation.
# - **Hint:** Use NumPy's matching statistical functions.
# - **Expected:** Sum **300**, mean **75**, median **75**, minimum **60**, maximum **90**.

# %% [markdown]
# ## 15. Matrix Multiplication
#
# Matrix multiplication combines rows from the first matrix with columns from the second matrix. The inner dimensions must match.
#
# ### Example 1: Multiply two 2 × 2 matrices
#
#
# - Matrix A contains rows **1, 2** and **3, 4**.
# - Matrix B contains rows **5, 6** and **7, 8**.
# - **Expected:** The result is **[19, 22]** and **[43, 50]**.
